# %%
transactions =[
    ["milk", "bread", "eggs"],
    ["milk", "bread", "butter"],
    ["milk", "bread", "eggs", "butter"],
    ["bread", "eggs"],
    ["milk", "butter"]
]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tranE= TransactionEncoder()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tranE.fit(transactions).columns_
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['bread', 'butter', 'eggs', 'milk']

# %%
encodedT=tranE.fit_transform(transactions)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
encodedT
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[ True, False,  True,  True],
#        [ True,  True, False,  True],
#        [ True,  True,  True,  True],
#        [ True, False,  True, False],
#        [False,  True, False,  True]])

# %%
df=pd.DataFrame(encodedT, columns=tranE.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    bread  butter   eggs   milk
# 0   True   False   True   True
# 1   True    True  False   True
# 2   True    True   True   True
# 3   True   False   True  False
# 4  False    True  False   True

# %%
from mlxtend.frequent_patterns import apriori
freqItemsets=apriori(df,min_support=0.12,use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
freqItemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                     itemsets
# 0       0.8                      (bread)
# 1       0.6                     (butter)
# 2       0.6                       (eggs)
# 3       0.8                       (milk)
# 4       0.4              (bread, butter)
# 5       0.6                (bread, eggs)
# 6       0.6                (milk, bread)
# 7       0.2               (butter, eggs)
# 8       0.6               (milk, butter)
# 9       0.4                 (milk, eggs)
# 10      0.2        (bread, eggs, butter)
# 11      0.4        (milk, bread, butter)
# 12      0.4          (milk, bread, eggs)
# 13      0.2         (milk, butter, eggs)
# 14      0.2  (milk, bread, eggs, butter)

# %%
from mlxtend.frequent_patterns import association_rules
rules= association_rules(freqItemsets,metric="confidence",min_threshold=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#               antecedents    consequents  antecedent support  \
# 0                 (bread)         (eggs)                 0.8
# 1                  (eggs)        (bread)                 0.6
# 2                  (milk)        (bread)                 0.8
# 3                 (bread)         (milk)                 0.8
# 4                  (milk)       (butter)                 0.8
# 5                (butter)         (milk)                 0.6
# 6          (butter, eggs)        (bread)                 0.2
# 7         (bread, butter)         (milk)                 0.4
# 8            (milk, eggs)        (bread)                 0.4
# 9          (butter, eggs)         (milk)                 0.2
# 10   (milk, butter, eggs)        (bread)                 0.2
# 11  (bread, eggs, butter)         (milk)                 0.2
# 12         (butter, eggs)  (milk, bread)                 0.2
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.6      0.6        0.75  1.250000      0.12         1.6
# 1                  0.8      0.6        1.00  1.250000      0.12         inf
# 2                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 3                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 4                  0.6      0.6        0.75  1.250000      0.12         1.6
# 5                  0.8      0.6        1.00  1.250000      0.12         inf
# 6                  0.8      0.2        1.00  1.250000      0.04         inf
# 7                  0.8      0.4        1.00  1.250000      0.08         inf
# 8                  0.8      0.4        1.00  1.250000      0.08         inf
# 9                  0.8      0.2        1.00  1.250000      0.04         inf
# 10                 0.8      0.2        1.00  1.250000      0.04         inf
# 11                 0.8      0.2        1.00  1.250000      0.04         inf
# 12                 0.6      0.2        1.00  1.666667      0.08         inf
#
#     zhangs_metric
# 0        1.000000
# 1        0.500000
# 2       -0.250000
# 3       -0.250000
# 4        1.000000
# 5        0.500000
# 6        0.250000
# 7        0.333333
# 8        0.333333
# 9        0.250000
# 10       0.250000
# 11       0.250000
# 12       0.500000

# %%
limitedCol=rules[['antecedents','consequents','support','confidence','lift']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
limitedCol
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               antecedents    consequents  support  confidence      lift
# 0                 (bread)         (eggs)      0.6        0.75  1.250000
# 1                  (eggs)        (bread)      0.6        1.00  1.250000
# 2                  (milk)        (bread)      0.6        0.75  0.937500
# 3                 (bread)         (milk)      0.6        0.75  0.937500
# 4                  (milk)       (butter)      0.6        0.75  1.250000
# 5                (butter)         (milk)      0.6        1.00  1.250000
# 6          (butter, eggs)        (bread)      0.2        1.00  1.250000
# 7         (bread, butter)         (milk)      0.4        1.00  1.250000
# 8            (milk, eggs)        (bread)      0.4        1.00  1.250000
# 9          (butter, eggs)         (milk)      0.2        1.00  1.250000
# 10   (milk, butter, eggs)        (bread)      0.2        1.00  1.250000
# 11  (bread, eggs, butter)         (milk)      0.2        1.00  1.250000
# 12         (butter, eggs)  (milk, bread)      0.2        1.00  1.666667

# %%
limitedCol[limitedCol['confidence']>=1]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               antecedents    consequents  support  confidence      lift
# 1                  (eggs)        (bread)      0.6         1.0  1.250000
# 5                (butter)         (milk)      0.6         1.0  1.250000
# 6          (butter, eggs)        (bread)      0.2         1.0  1.250000
# 7         (bread, butter)         (milk)      0.4         1.0  1.250000
# 8            (milk, eggs)        (bread)      0.4         1.0  1.250000
# 9          (butter, eggs)         (milk)      0.2         1.0  1.250000
# 10   (milk, butter, eggs)        (bread)      0.2         1.0  1.250000
# 11  (bread, eggs, butter)         (milk)      0.2         1.0  1.250000
# 12         (butter, eggs)  (milk, bread)      0.2         1.0  1.666667

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.frequent_patterns import fpgrowth
# %timeit fpgrowth(df,min_support=0.12,use_colnames=True)
# %timeit apriori(df,min_support=0.12,use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 1.92 ms ± 367 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.16 ms ± 245 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
